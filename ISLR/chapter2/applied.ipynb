# %% [markdown]
# This is the code associated with answering the questions for 8 - 10 in chapter 2

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### part a

# %%
import pandas as pd

college_df = pd.read_csv("../data/College.csv")
college_df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ### part b

# %%
college_df.rename(columns={'Unnamed: 0': 'Name'}, inplace=True)
college_df.set_index('Name', inplace=True)
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Name
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Name
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# ### part c

# %% [markdown]
# #### part i

# %%
college_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# #### part ii

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

attributes = list(college_df)[0:10]
# plotting the first 10  attributes against each other
scatter_matrix(college_df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10cec07f0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1127646a0>]], dtype=object)

# %%
college_df.boxplot(column="Outstate", by="Private")

# %% [markdown]
# #### part iv

# %%
college_df['Elite'] = college_df['Top10perc'] > 50

# %%
college_df['Elite'].value_counts()
# Out:
# False    699
# True      78
# Name: Elite, dtype: int64

# %%
college_df.boxplot(column='Outstate', by='Elite')

# %% [markdown]
# ## Exercise 9

# %%
auto_df = pd.read_csv("../data/Auto.csv")
auto_df.dropna(inplace=True)
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### part a

# %%
auto_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
auto_df = auto_df[auto_df['horsepower'] != '?']
auto_df['horsepower'] = auto_df['horsepower'].astype(int)

# %% [markdown]
# qualitative = origin and name;
# quantitative = mpg, cylinders, displacement, horsepower, weight, acceleration, and year

# %% [markdown]
# ### part b

# %%
quantitative_cols = ['mpg', 'cylinders', 'displacement', 'horsepower',
                     'weight', 'year']
for column in quantitative_cols:
    print("Range for {}: {}".format(column, (auto_df[column].max() - auto_df[column].min())))
# Out:
# Range for mpg: 37.6
# Range for cylinders: 5
# Range for displacement: 387.0
# Range for horsepower: 184
# Range for weight: 3527
# Range for year: 12

# %% [markdown]
# ### part c

# %%
for column in quantitative_cols:
    print("Mean and Std for {}: {}, {}".format(column, auto_df[column].mean(), auto_df[column].std()))
# Out:
# Mean and Std for mpg: 23.44591836734694, 7.805007486571799
# Mean and Std for cylinders: 5.471938775510204, 1.7057832474527843
# Mean and Std for displacement: 194.41198979591837, 104.64400390890465
# Mean and Std for horsepower: 104.46938775510205, 38.49115993282855
# Mean and Std for weight: 2977.5841836734694, 849.4025600429494
# Mean and Std for year: 75.9795918367347, 3.6837365435778318

# %% [markdown]
# ### part d

# %%
modified_dataset = auto_df.drop(auto_df.index[9:86])
for column in quantitative_cols:
    print("Range, mean and std for {}: {}, {}".format(column, (modified_dataset[column].max() - modified_dataset[column].min()),modified_dataset[column].mean(), modified_dataset[column].std()))
# Out:
# Range, mean and std for mpg: 35.6, 24.437460317460314
# Range, mean and std for cylinders: 5, 5.365079365079365
# Range, mean and std for displacement: 387.0, 186.86984126984126
# Range, mean and std for horsepower: 184, 100.56507936507937
# Range, mean and std for weight: 3348, 2933.6349206349205
# Range, mean and std for year: 12, 77.15873015873017

# %% [markdown]
# ### part e

# %%
scatter_matrix(auto_df[quantitative_cols], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115801b70>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118bd60f0>]], dtype=object)

# %% [markdown]
# ### part f

# %% [markdown]
# weight, cyliners, horsepower, displacement

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# ### Part a

# %%
from sklearn.datasets import load_boston
import numpy as np
boston_df = pd.read_csv('../data/boston.csv')
print(boston_df.shape)
boston_df.head()
# Out:
# (506, 15)
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston_df.drop('Unnamed: 0', inplace=True, axis=1)

# %% [markdown]
# There are 506 observations of suburbs and 14 features

# %% [markdown]
# ### Part c

# %%
abs(boston_df.corr()['crim'])
# Out:
# crim       1.000000
# zn         0.200469
# indus      0.406583
# chas       0.055892
# nox        0.420972
# rm         0.219247
# age        0.352734
# dis        0.379670
# rad        0.625505
# tax        0.582764
# ptratio    0.289946
# black      0.385064
# lstat      0.455621
# medv       0.388305
# Name: crim, dtype: float64

# %% [markdown]
# index of accessibility to radial highways, full-value property-tax rate, lower status of the populatioin

# %% [markdown]
# ### Part d

# %%
quantitative_cols = ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad',
                     'tax', 'ptratio', 'black', 'lstat', 'medv']
for column in quantitative_cols:
    print("Range for {}: {}".format(column, (boston_df[column].max() - boston_df[column].min())))
# Out:
# Range for crim: 88.96988
# Range for zn: 100.0
# Range for indus: 27.279999999999998
# Range for nox: 0.486
# Range for rm: 5.218999999999999
# Range for age: 97.1
# Range for dis: 10.9969
# Range for rad: 23
# Range for tax: 524
# Range for ptratio: 9.4
# Range for black: 396.58
# Range for lstat: 36.24
# Range for medv: 45.0

# %%
boston_df[['crim', 'tax', 'ptratio']].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677082  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# ### Part e

# %%
print(len(boston_df[boston_df['chas'] == 1]))
# Out:
# 35

# %% [markdown]
# ### Part f

# %%
boston_df['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# ### Part g

# %%
boston_df[boston_df.medv == boston_df.medv.min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %% [markdown]
# town 398 has the highest number of black people; both towns have a very high crime rate, in the bottom 25% of rooms per dwelling,

# %% [markdown]
# ### Part h

# %%
rm_g7 = boston_df[boston_df['rm'] > 7]
print(len(rm_g7))
rm_g8 = boston_df[boston_df['rm'] > 8]
print(len(rm_g8))

rm_g8.describe()
# Out:
# 64
# 13
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio       black  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...

# %% [markdown]
# These places have a greater proportion of blacks, a higher median value of owener occupied homes, and a lower crim rate per capita.
